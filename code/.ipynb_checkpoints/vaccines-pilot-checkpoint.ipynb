# %%
# !pip install pandas pyarrow scikit-learn scipy numpy

# %%
# !pip install mlxtend

# %%
# !pip install plotly jupyterlab-dash seaborn bokeh

# %%
import pyarrow
import pandas as pd
import sklearn

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.io as pio
pio.renderers.default='notebook'

from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource

# %%
df = pd.read_csv("../data/GSE169159_covid2.csv")

# %%
df
# Out:
#        Dataset         uid geo_accession  biosample_accession    Donor  Age  \
# 0    GSE169159  PID2000_BL    GSM5900795                  NaN  PID2000   30
# 1    GSE169159  PID2000_BL    GSM5900795                  NaN  PID2000   30
# 2    GSE169159  PID2000_BL    GSM5900795                  NaN  PID2000   30
# 3    GSE169159  PID2000_BL    GSM5900795                  NaN  PID2000   30
# 4    GSE169159  PID2000_BL    GSM5900795                  NaN  PID2000   30
# ..         ...         ...           ...                  ...      ...  ...
# 219  GSE169159  PID2056_BL    GSM5900715                  NaN  PID2056   50
# 220  GSE169159  PID2056_BL    GSM5900715                  NaN  PID2056   50
# 221  GSE169159  PID2056_BL    GSM5900715                  NaN  PID2056   50
# 222  GSE169159  PID2056_BL    GSM5900715                  NaN  PID2056   50
# 223  GSE169159  PID2056_BL    GSM5900715                  NaN  PID2056   50
#
#        IMMAGE Gender       Virus Vaccine         Strain      Day     Response  \
# 0    0.283830   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2      D21    62.341066
# 1    0.283830   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2       D0    10.000000
# 2    0.283830   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2   FC.D42   146.480634
# 3    0.283830   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2  D90-120   666.000000
# 4    0.283830   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2      D42  1464.806335
# ..        ...    ...         ...     ...            ...      ...          ...
# 219  0.343553   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2  D90-120   466.000000
# 220  0.343553   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2      D42   387.336801
# 221  0.343553   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2      D21    33.072837
# 222  0.343553   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2   FC.D42    38.733680
# 223  0.343553   Male  SARS-CoV-2  Pfizer  WT SARS-CoV-2   FC.D90    46.600000
#
#              Cohort
# 0    healthy adults
# 1    healthy adults
# 2    healthy adults
# 3    healthy adults
# 4    healthy adults
# ..              ...
# 219  healthy adults
# 220  healthy adults
# 221  healthy adults
# 222  healthy adults
# 223  healthy adults
#
# [224 rows x 14 columns]

# %%
# Keep only the data of the sample time (post vaccine days) we want.
# Todo: decide on the correct day per vaccince type
day_col = "Day"
sample_day = "FC.D21"
df = df.loc[df[day_col] == sample_day]

# %%
# Need to find out what's considered a "high" (=protective?) response.  
# For the meantime, take the average response as the threshold
response_col = "Response"
responses = df[[response_col]]
mean_response = responses.mean()
print(f'mean_response: {mean_response}')
# Out:
# mean_response: Response    3.386266
# dtype: float64

# %%
feature_col = "IMMAGE"
# Note the double [[]], which keeps X as a DF and not a series - sklearn expects a 2D array-like structure which a 1-feature DF supplies
X = df[[feature_col]]

# Get a boolean map of sub and above threshold values
high_response_thr = mean_response
y = df[[response_col]] > high_response_thr
# Convert boolean Series to 0s and 1s and rename column
y = y.astype(int).rename(columns={'Response': 'Labels'})

# %% [markdown]
# #### Looking at the distribution of response values

# %%
sns.scatterplot(x='Data', y=['']*len(df), hue='Label', data=df, jitter=True, dodge=True, palette='Set1')
plt.show()

# %%
sns.histplot(responses, bins=50)
plt.show()

# %%
data = pd.concat([X, responses, y], axis=1)
data

# %%
sns.scatterplot(data=data, x="IMMAGE", y="Response", hue="Labels", palette='Set1')
plt.show()

# %%
sns.stripplot(data=data, x='IMMAGE', y=['']*len(df), hue='Labels', jitter=False, dodge=True, palette='Set1')
plt.show()

# %% [markdown]
# So we see that the assumption that response is linear with IMMAGE doesn't hold...

# %%
# Scikit-learn related imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_validate, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from scipy.stats import randint
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from mlxtend.plotting import plot_decision_regions


# Training and prediction 
svm = SVC()
svm_poly = SVC(kernel='poly')
log_regress = LogisticRegression()

# %% [markdown]
# ### Testing out some basic predictions

# %% [markdown]
# #### logistic regression

# %%
labels = y["Labels"]

log_regress = LogisticRegression()
regression_result = cross_validate(log_regress, X, labels)
regression_result['test_score']
# Out:
# array([0.57142857, 0.71428571, 0.66666667, 0.66666667, 0.66666667])

# %%
# Split the data into training and testing sets
X_train, X_test, labels_train, labels_test = train_test_split(X, labels, test_size=0.2, random_state=42)

log_regress.fit(X_train, labels_train)
log_regress.score(X_test, labels_test)
# Out:
# 0.5714285714285714

# %% [markdown]
# #### Cross validation (SVM, linear)

# %%
svm_result = cross_validate(svm, X, y)
svm.fit(X, Y)

# %%
svm_result['test_score']
svm_linear_score = svm_result['test_score'].mean()

# %% [markdown]
# #### Cross validation (SVM, polynomial up to 3rd degree)

# %%
svm_poly_result = cross_validate(svm_poly, X, y)
svm_poly_score = svm_poly_result['test_score'].mean()

# %%
print(f"All fold scores:{svm_poly_result['test_score']}")
print(f"Mean score: {svm_poly_result['test_score'].mean()}")
# Out:
# All fold scores:[0.57142857 0.71428571 0.66666667 0.66666667 0.66666667]
# Mean score: 0.657142857142857

# %% [markdown]
# #### CV with hyperparameter tuning  (Decision forest)

# %%
# define the parameter space that will be searched over
param_distributions = {'max_depth': randint(5, 10)}
tree_search = RandomizedSearchCV(estimator=DecisionTreeClassifier(random_state=0),
                             n_iter=10,
                             param_distributions=param_distributions,
                             random_state=0)
tree_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=DecisionTreeClassifier(random_state=0),
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002C9A2BBE9B0>},
#                    random_state=0)

# %%
tree_score = tree_search.score(X_test, y_test)

# %%
# define the parameter space that will be searched over
param_distributions = {'n_estimators': randint(1, 5),
                        'max_depth': randint(5, 10)}
forest_search = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=0),
                             n_iter=10,
                             param_distributions=param_distributions,
                             random_state=0)
forest_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=0),
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002C9A2AFE110>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002C9A7C38DF0>},
#                    random_state=0)

# %%
forest_score = forestSearch.score(X_test, y_test)

# %%
## so far we have:

print(f"Linear SVM score: {svm_linear_score:.2}")
print(f"Polynomial SVM score: {svm_poly_score:.2}")
print(f"forest score: {forest_score}")
# Out:
# Linear SVM score: 0.66
# Polynomial SVM score: 0.66
# forest score: 0.25

# %% [markdown]
# ### Looking at decision boundaries/threshold

# %%
beta_0 = log_regress.intercept_[0]
beta_1 = log_regress.coef_[0][0]

# Calculate the cutoff value
cutoff = -beta_0 / beta_1

print(f"The cutoff value for the feature is: {cutoff}")
# Out:
# The cutoff value for the feature is: -2.8168146509052705

# %%
beta_1
# Out:
# -0.23640259187679533

# %%
best_tree = tree_search.best_estimator_
plot_tree(best_tree)
# Out:
# [Text(0.25, 0.9166666666666666, 'x[0] <= 0.27\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.125, 0.75, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.375, 0.75, 'x[0] <= 0.339\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.25, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.5833333333333334, 'x[0] <= 0.45\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.375, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.625, 0.4166666666666667, 'x[0] <= 0.478\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.5, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.25, 'x[0] <= 0.645\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.625, 0.08333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.875, 0.08333333333333333, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]')]

# %%
y_test
# Out:
# 82     1
# 156    1
# 75     1
# 14     0
# 116    0
# 99     1
# 196    0
# 183    1
# Name: Response, dtype: int32

# %%
plot_decision_regions(X.to_numpy(), y.to_numpy(), clf=svm, legend=2)

# Adding axes annotations
plt.xlabel('IMMAGE score')
plt.title('SVM classification')

plt.show()
# Out:
# C:\Users\Jonathan\AppData\Roaming\pypoetry\venv\lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but SVC was fitted with feature names
